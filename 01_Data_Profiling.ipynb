# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('ONINE_FOOD_DELIVERY_ANALYSIS.csv')
df.head()
# Out:
#     Order_ID Customer_ID  Customer_Age Customer_Gender     City     Area  \
# 0  ORD000001    CUST6948          19.0            Male      NaN  Central
# 1  ORD000002    CUST6515           NaN          Female  Chennai    North
# 2  ORD000003    CUST1765           NaN            Male    Delhi      NaN
# 3  ORD000004    CUST2744           NaN            Male   Mumbai  Central
# 4  ORD000005    CUST4389          57.0          Female  Chennai    South
#
#   Restaurant_ID Restaurant_Name Cuisine_Type  Order_Date  ... Final_Amount  \
# 0        RES936   Restaurant_29      Chinese  10/20/2024  ...          NaN
# 1        RES689  Restaurant_419      Chinese   8/12/2024  ...       4849.0
# 2        RES723  Restaurant_244      Arabian   12/8/2024  ...        737.0
# 3        RES951  Restaurant_178      Chinese   10/8/2024  ...          NaN
# 4        RES419  Restaurant_262      Chinese    2/4/2024  ...        352.0
#
#    Payment_Mode  Order_Status  Cancellation_Reason  Delivery_Partner_ID  \
# ...

# %%
print("Rows:", df.shape[0])
print("Columns:", df.shape[1])
# Out:
# Rows: 100000
# Columns: 25

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 25 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Order_ID             100000 non-null  object
#  1   Customer_ID          100000 non-null  object
#  2   Customer_Age         49907 non-null   float64
#  3   Customer_Gender      75144 non-null   object
#  4   City                 83274 non-null   object
#  5   Area                 83315 non-null   object
#  6   Restaurant_ID        100000 non-null  object
#  7   Restaurant_Name      100000 non-null  object
#  8   Cuisine_Type         83115 non-null   object
#  9   Order_Date           98986 non-null   object
#  10  Order_Time           98002 non-null   object
#  11  Delivery_Time_Min    66641 non-null   float64
#  12  Distance_km          66530 non-null   float64
#  13  Order_Value          66673 non-null   float64
# ...

# %%
missing = df.isnull().sum()

missing_df = pd.DataFrame({
    'Missing Count': missing,
    'Missing %': round((missing/len(df))*100,2)
})

missing_df.sort_values('Missing %', ascending=False)
# Out:
#                      Missing Count  Missing %
# Cancellation_Reason          90969      90.97
# Final_Amount                 55697      55.70
# Customer_Age                 50093      50.09
# Distance_km                  33470      33.47
# Delivery_Time_Min            33359      33.36
# Order_Value                  33327      33.33
# Peak_Hour                    32962      32.96
# Customer_Gender              24856      24.86
# Payment_Mode                 19911      19.91
# Cuisine_Type                 16885      16.89
# City                         16726      16.73
# Discount_Applied             16715      16.72
# Area                         16685      16.68
# Delivery_Rating              16523      16.52
# Order_Time                    1998       2.00
# Order_Date                    1014       1.01
# Order_ID                         0       0.00
# Restaurant_Name                  0       0.00
# Restaurant_ID                    0       0.00
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
for col in df.columns:
    print(col, df[col].nunique())
# Out:
# Order_ID 100000
# Customer_ID 8999
# Customer_Age 43
# Customer_Gender 3
# City 5
# Area 5
# Restaurant_ID 900
# Restaurant_Name 500
# Cuisine_Type 5
# Order_Date 365
# Order_Time 1
# Delivery_Time_Min 232
# Distance_km 3402
# Order_Value 4052
# Discount_Applied 5
# Final_Amount 4574
# Payment_Mode 4
# Order_Status 2
# Cancellation_Reason 3
# Delivery_Partner_ID 900
# Delivery_Rating 5
# Restaurant_Rating 26
# Order_Day 2
# Peak_Hour 2
# Profit_Margin 71

# %%
df.describe()
# Out:
#        Customer_Age  Delivery_Time_Min   Distance_km   Order_Value  \
# count  49907.000000       66641.000000  66530.000000  66673.000000
# mean      38.976516         127.475923     16.449242   2081.830126
# std       12.372157          90.805839     12.256742   1553.628891
# min       18.000000          20.000000      1.000000    150.000000
# 25%       28.000000          45.000000      5.470000    673.000000
# 50%       39.000000         120.000000      9.970000   1197.000000
# 75%       50.000000         210.000000     27.430000   3494.000000
# max       60.000000         300.000000     40.000000   5000.000000
#
#        Discount_Applied  Final_Amount  Delivery_Rating  Restaurant_Rating  \
# count      83285.000000  44303.000000     83477.000000      100000.000000
# mean          93.936243   1961.101190         2.991531           4.249680
# std          108.209904   1557.354417         1.414108           0.722554
# ...

# %%
df[df['Delivery_Rating'] > 5]
# Out:
# Empty DataFrame
# Columns: [Order_ID, Customer_ID, Customer_Age, Customer_Gender, City, Area, Restaurant_ID, Restaurant_Name, Cuisine_Type, Order_Date, Order_Time, Delivery_Time_Min, Distance_km, Order_Value, Discount_Applied, Final_Amount, Payment_Mode, Order_Status, Cancellation_Reason, Delivery_Partner_ID, Delivery_Rating, Restaurant_Rating, Order_Day, Peak_Hour, Profit_Margin]
# Index: []
#
# [0 rows x 25 columns]

# %%
df[df['Profit_Margin'] < 0]
# Out:
#         Order_ID Customer_ID  Customer_Age Customer_Gender       City   Area  \
# 14     ORD000015    CUST8064          28.0             NaN      Delhi   East
# 17     ORD000018    CUST2861           NaN             NaN  Hyderabad   West
# 18     ORD000019    CUST1044          52.0          Female      Delhi   East
# 20     ORD000021    CUST1786           NaN             NaN     Mumbai  North
# 25     ORD000026    CUST2566          24.0          Female      Delhi  North
# ...          ...         ...           ...             ...        ...    ...
# 99982  ORD099983    CUST3056          44.0            Male  Hyderabad   East
# 99986  ORD099987    CUST3286           NaN             NaN     Mumbai    NaN
# 99987  ORD099988    CUST3525          43.0            Male        NaN    NaN
# 99994  ORD099995    CUST9174           NaN          Female      Delhi   East
# 99996  ORD099997    CUST6158           NaN            Male     Mumbai   East
#
# ...

# %%
pd.crosstab(
    df['Order_Status'],
    df['Cancellation_Reason'].isnull()
)
# Out:
# Cancellation_Reason  False  True
# Order_Status
# Cancelled             9031   6005
# Delivered                0  84964

# %%
sample = df[
    df['Final_Amount'].notna() &
    df['Order_Value'].notna() &
    df['Discount_Applied'].notna()
]

sample[['Order_Value',
        'Discount_Applied',
        'Final_Amount']].head(20)
# Out:
#     Order_Value  Discount_Applied  Final_Amount
# 1        4869.0              20.0        4849.0
# 2         757.0              20.0         737.0
# 4         372.0              20.0         352.0
# 7        3506.0              20.0        3486.0
# 8         525.0             100.0         425.0
# 9        4691.0              50.0        4641.0
# 10       4881.0             100.0        4781.0
# 12        417.0              20.0         397.0
# 14       4017.0             300.0        3717.0
# 16       4218.0              20.0        4198.0
# 20        355.0             100.0         255.0
# 21       1046.0             300.0         746.0
# 22       1060.0              50.0        1010.0
# 25        483.0              20.0         463.0
# 29       2553.0              50.0        2503.0
# 35        999.0             100.0         899.0
# 38        672.0              50.0         622.0
# 40       1126.0              20.0        1106.0
# 42        870.0              50.0         820.0
# ...

# %%
df[df['Final_Amount'] < 0]
# Out:
#         Order_ID Customer_ID  Customer_Age Customer_Gender       City  \
# 104    ORD000105    CUST8820           NaN          Female      Delhi
# 132    ORD000133    CUST5296          57.0           Other    Chennai
# 284    ORD000285    CUST5963          44.0             NaN    Chennai
# 306    ORD000307    CUST7962          19.0             NaN      Delhi
# 359    ORD000360    CUST7405          30.0           Other        NaN
# ...          ...         ...           ...             ...        ...
# 99645  ORD099646    CUST2374           NaN             NaN    Chennai
# 99681  ORD099682    CUST8915          51.0          Female  Bangalore
# 99870  ORD099871    CUST8481          49.0          Female        NaN
# 99939  ORD099940    CUST5924          59.0             NaN  Hyderabad
# 99961  ORD099962    CUST6135           NaN            Male      Delhi
#
#           Area Restaurant_ID Restaurant_Name Cuisine_Type Order_Date  ...  \
# ...

# %%
df[df['Restaurant_Rating'] > 5]
# Out:
#         Order_ID Customer_ID  Customer_Age Customer_Gender       City  \
# 19     ORD000020    CUST8005          53.0            Male  Bangalore
# 24     ORD000025    CUST9940          45.0           Other    Chennai
# 25     ORD000026    CUST2566          24.0          Female      Delhi
# 27     ORD000028    CUST4677          34.0           Other     Mumbai
# 33     ORD000034    CUST1629           NaN            Male  Bangalore
# ...          ...         ...           ...             ...        ...
# 99976  ORD099977    CUST8271           NaN            Male     Mumbai
# 99977  ORD099978    CUST5981          19.0          Female        NaN
# 99982  ORD099983    CUST3056          44.0            Male  Hyderabad
# 99987  ORD099988    CUST3525          43.0            Male        NaN
# 99994  ORD099995    CUST9174           NaN          Female      Delhi
#
#           Area Restaurant_ID Restaurant_Name Cuisine_Type  Order_Date  ...  \
# ...

# %%
df[df['Restaurant_Rating'] > 5].shape
# Out:
# (18019, 25)

# %%
df[df['Profit_Margin'] < 0].shape
# Out:
# (27733, 25)

# %%
df[df['Final_Amount'] < 0].shape
# Out:
# (773, 25)

# %%
df[df['Restaurant_Rating'] > 5]['Restaurant_Rating'].value_counts()
# Out:
# Restaurant_Rating
# 5.2    4054
# 5.1    4031
# 5.3    4016
# 5.4    3876
# 5.5    2042
# Name: count, dtype: int64

# %%
df['Restaurant_Rating'] = np.where(
    df['Restaurant_Rating'] > 5,
    5,
    df['Restaurant_Rating']
)

# %%
df[df['Restaurant_Rating'] > 5]['Restaurant_Rating'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
df['Peak_Hour'].value_counts(dropna=False)
# Out:
# Peak_Hour
# False    33585
# True     33453
# NaN      32962
# Name: count, dtype: int64

# %%
df[df['Final_Amount'] < 0][[
    'Order_Value',
    'Discount_Applied',
    'Final_Amount'
]].head(20)
# Out:
#       Order_Value  Discount_Applied  Final_Amount
# 104         187.0             300.0        -113.0
# 132         175.0             300.0        -125.0
# 284         246.0             300.0         -54.0
# 306         194.0             300.0        -106.0
# 359         285.0             300.0         -15.0
# 576         247.0             300.0         -53.0
# 619         234.0             300.0         -66.0
# 729         210.0             300.0         -90.0
# 891         195.0             300.0        -105.0
# 1148        204.0             300.0         -96.0
# 1517        254.0             300.0         -46.0
# 1589        245.0             300.0         -55.0
# 1683        286.0             300.0         -14.0
# 1777        210.0             300.0         -90.0
# 1813        167.0             300.0        -133.0
# 2099        295.0             300.0          -5.0
# 2149        221.0             300.0         -79.0
# 2705        176.0             300.0        -124.0
# ...

# %%
numeric_cols = df.select_dtypes(include='number').columns

for col in numeric_cols:
    print(f"\n{col}")

    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    outliers = df[
        (df[col] < lower) |
        (df[col] > upper)
    ]

    print("Outliers:", len(outliers))
# Out:
# Customer_Age
# Outliers: 0
#
# Delivery_Time_Min
# Outliers: 0
#
# Distance_km
# Outliers: 0
#
# Order_Value
# Outliers: 0
#
# Discount_Applied
# Outliers: 16600
#
# Final_Amount
# Outliers: 0
#
# Delivery_Rating
# Outliers: 0
#
# Restaurant_Rating
# Outliers: 0
#
# Profit_Margin
# Outliers: 0

# %%
df['Restaurant_Rating'] = df['Restaurant_Rating'].clip(upper=5)
